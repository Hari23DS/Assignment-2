# %%
j = 1
for i in range(1, 10):
    if i < 6:
        print('*' * i)
    if i > 5:
        print('*' * (i - j*2))
        j = j + 1
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
print(input()[::-1])
# Out:
# ineuron
# norueni
